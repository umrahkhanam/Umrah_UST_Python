# %% [markdown]
# # getpass

# %%
import getpass  #for using get pass we have to import the library(inbuilt)
c=getpass.getpass("Password")
# print(c)

# %%
import getpass
c=getpass.getpass("Enter your password: ")  #secure way
# c=input("Enter your password: ")   #not secure
if c=='ashish':
    print("password match")
else:
    print("Incorrect password")

# %% [markdown]
# # Sending Email

# %%
# for sending email we have to import smtplib
import smtplib

# %%
with smtplib.SMTP('smtp.gmail.com',5  87)as smtp:  #tls -587  ssl-465
#     to check connection is responding or not
    print(smtp.noop())  
    print(smtp.helo())  
    print(smtp.ehlo())
# Out:
# (250, b'2.0.0 OK r10sm16366650pgk.74 - gsmtp')
# (250, b'smtp.gmail.com at your service')
# (250, b'smtp.gmail.com at your service, [2406:7400:63:f6fb:b89d:8a63:17c7:558b]\nSIZE 35882577\n8BITMIME\nSTARTTLS\nENHANCEDSTATUSCODES\nPIPELINING\nCHUNKING\nSMTPUTF8')

# %%
import smtplib
smtp_object=smtplib.SMTP('smtp.gmail.com',587)
print(smtp_object.starttls())

# %%
# less secure app

# %%
import smtplib
import getpass

smtp_object=smtplib.SMTP('smtp.gmail.com',587)
smtp_object.starttls()
# print('connected to tls')
email=input("Enter your email:")
pasword=getpass.getpass("Enter your password:") 

smtp_object.login(email,pasword)
print('login successfull')
smtp_object.quit()

# %%
import smtplib
import getpass

email=input("Enter your mail id:")
password=getpass.getpass("ENter your password:")#16 digit generated passowrd

rec_mailid='umrahkhanam@gmail.com' #or you can send mail to multiple id by creating list['abc@g.com','xyz@gmail.com']
subject= 'Welcome Mail'
body="Please click this link to get 5rs..."

msg="Subject: "+subject+'\n'+body
# msg=subject+body

obj=smtplib.SMTP('smtp.gmail.com',587)
obj.starttls()
obj.login(email,password)

obj.sendmail(email,rec_mailid,msg)
print("mail sent")
obj.quit()

# %% [markdown]
# # Receiving Mail

# %%
import imaplib
import getpass
m=imaplib.IMAP4_SSL('imap.gmail.com')
e='ashishprashar37@gmail.com'#input("Enter your email:")
p=getpass.getpass("Enter password:")
m.login(e,p)#okrmdingoypheskw
print('login success')
m.logout()
print("logout success")

# %%
import imaplib
import getpass
m=imaplib.IMAP4_SSL('imap.gmail.com')
e='ashishprashar37@gmail.com'#input("Enter your email:")
p=getpass.getpass("Enter password:")
m.login(e,p)#okrmdingoypheskw
print('login success')
print(m.list())
m.logout()
print("logout success")

# %%
import imaplib
import getpass
m=imaplib.IMAP4_SSL('imap.gmail.com')
e='ashishprashar37@gmail.com'#input("Enter your email:")
p=getpass.getpass("Enter password:")
m.login(e,p)#okrmdingoypheskw
# print('login success')
print(m.select('INBOX'))#connect to inbox
# m.search('')
print(m.logout())
print("logout success")

# %%
import imaplib
import getpass
import email

email_id='ashishprashar37@gmail.com'
email_pass=getpass.getpass("Enter password: ")
mail=imaplib.IMAP4_SSL('imap.gmail.com')
mail.login(email_id,email_pass)
mail.select('INBOX')
# typ, data = mail.search(None, 'ALL')
typ,data=mail.fetch(b'53','(RFC822)')
msg=email.message_from_string(data[0][1].decode('utf-8'))
for i in msg.walk():
    print(i)

# %%
import imaplib
import email,getpass
email_id='ashishprashar37@gmail.com'
email_pass=getpass.getpass("Enter password: ")
mail=imaplib.IMAP4_SSL('imap.gmail.com')#creating secure connection
mail.login(email_id,email_pass)
mail.select("inbox")

# ph,s_data=mail.search(None,'ALL')
p_holder,s_data=mail.search(None,'UNSEEN')

for i in s_data[0].split():
    print(i)
    p_holder,f_data=mail.fetch(i,'(RFC822)')
    print(f_data)

# %%
import imaplib
import email
import getpass
email_id='ashishprashar37@gmail.com'
email_pass=getpass.getpass("Enter password: ")
mail=imaplib.IMAP4_SSL('imap.gmail.com')#creating secure connection
mail.login(email_id,email_pass)
mail.select("inbox")

# ph,s_data=mail.search(None,'ALL')
p_holder,s_data=mail.search(None,'UNSEEN')

for i in s_data[0].split():
    p_holder,f_data=mail.fetch(i,'(RFC822)')
    p_holder,exp_data=f_data[0]  #expaining data
#     print(exp_data)
    email_msg=email.message_from_bytes(exp_data)
    print(email_msg)

# %%
import imaplib
import email
import getpass
email_id='ashishprashar37@gmail.com'
email_pass=getpass.getpass("Enter password: ")
mail=imaplib.IMAP4_SSL('imap.gmail.com')#creating secure connection
mail.login(email_id,email_pass)
mail.select("inbox")

# ph,s_data=mail.search(None,'ALL')
p_holder,s_data=mail.search(None,'UNSEEN')

for i in s_data[0].split():
    p_holder,f_data=mail.fetch(i,'(RFC822)')
    p_holder,exp_data=f_data[0]  #expaining data
    email_msg=email.message_from_bytes(exp_data)
    for j in email_msg.walk():
        if j.get_content_type()=="text/plain":
            body=j.get_payload()
            print(body)
# Out:
# Enter password: ········
# Your email client cannot read this email.
# To view it online, please go here:
# http://em.internshala.com/display.php?M=68936035&C=18300064867&S=14292&L=4775&N=9812
#
#
# To stop receiving these
# emails:http://em.internshala.com/unsubscribe.php?M=68936035&C=18300064867&L=4775&N=14292
#
# *BHARATIYA VIDYA BHAVAN*
#
# *BHAVAN=E2=80=99S PRIYAMVADA BIRLA INSTITUTE OF MANAGEMENT*
#
# Campus/Admission:
#
# CA-14, Vijayanagar 1st Stage, Mysore 570 017, India.
#
# Phone: +91-821-2413390 / 91 Fax: +91-821-2412141
#
# E-mail: bpbimmysore@gmail.com Website: www.bpbim.org
#
#
#
# *ADMISSION TO AICTE APPROVED PGDM PROGRAMME 2018 =E2=80=93 20*
#
#
# *Dear Students,*
#
#
#
# Congratulation for completing graduation and we wish you to have a bright
# career and future. Fresh graduates seek their dream career or go for higher
# education after graduation. For setting dream career, employability is very
# much essential and for higher education, dedication and commitment to gain
# knowledge is essential.
#
#
# Get the Knowledge, Learn the Skill and be ready to grab the Job in this
# competitive world. Join our prestigious Institute to undergo the training
# for life skills and career development. Our Institute, BPBIM offers *Two
# Years Full Time PGDM Programme 2018 =E2=80=93 20 (brochure enclosed)*
#
#
#
# Admission process  -  *Filled in Application Form and the photocopies of
# all Academic Documents listed below and *a *DD** for Rs.5,000/-* as
# registration fee drawn in the favor of *=E2=80=98"Bhavan=E2=80=99s Priyamva=
# da Birla
# Institute of Management=E2=80=99" payable at Mysore **(*this will be adjust=
# ed
# towards the *first year fee)* to be submitted.
#
#
#
# *a.*   *Matriculation Marks Card*
#
# *b.*   *Pre University Marks Card*
#
# *c.*   *All Degree Marks Cards*
#
# *d.*   *Degree Certificate issued by the University or Provisional Degree
# Certificate issued by the college.*
#
# *e.   Entrance Exam score card (MAT / CAT / XAT / KMAT / PGCET etc)*
#
# *f.*   *Seven latest passport size colour photographs apart from the one
# which is pasted on the Application Form.*
#
#
#
# All the *original academic documents* shall be collected at the time of
# admission, which is absolutely essential for *obtaining admission* *approva=
# l
# from AICTE*.
#
#
#
# The Fee structure for two Years is *Rs.3,15,000/- (Rupees Three Lakhs
# Fifteen thousand Only)*
#
# *a.*   *First Year total payment                            -
# Rs.1,65,000/-*
#
# * (Payable before commencement of  I Year)*
#
#
#
# *b.*   *Second Year total payment                         -
#  Rs.1,50,000/-*
#
# *                 (Payable before commencement of II Year)*
#
#
#
#       The *Students shall receive* the following, however, it is not
# limited to these :-
#
# Study Material, Blazer, 4 MBPS wireless Internet Connectivity @
# campus, Orientation Program, Yoga Classes, Industrial Visits, Communication
# Skills, Management Fests, personality development courses, Interaction with
# Business Leaders under Business Leadership Forum, Out Bound Learning
# Program, Village vocational venture, etc.
#
#
# *Optional:*
#
# *1)  Singapore International Educational Trip*
#
# *2)  Laptop*
#
#
#
#
#
#  Hostel Facilities available. Call: 9945073034
#
#
# *For Further Query call: 8884746466*
#
# --=20
# Regards,
#
# Shashikala.K
# BPBIM
#
# $timestamp
# Video In Focus!
#
#
# This is Aarnav Jain - an optimistic, go-getter, curious, enthusiastic and responsible individual. And his Vyre Video Profile is our 'Video Profile In Focus'.
#
#
# []( )
# You too can be featured by us. You too can get on top of the recruiter's shortlist like Aarnav. All you need to do is record and upload your 90-second video pitch on Vyre.
#
# You can take a few tips from Aarnav or use your own creativity to showcase your talents. To help you perfect your video, we have added an 'Edit Video' feature on the platform. Do check it out!
#
#
#
# If you have any questions, regarding Vyre or your video - feel free to write to us at support@vyre.co.
#
# So don't waste time, upload your video ASAP! Who knows you could be our next 'Video Profile In Focus'
#
# Regards,
# The Vyre Team
#
# Vyre Technology Labs Pvt. Ltd.
#
# #203, 2nd Floor, Evoma Business Center, No. 88 Borewell Road, Opposite Whitefield Post Office, Whitefield, Bengaluru, Karnataka 560066
#
# If you are no longer interested, you can [ unsubscribe instantly ]( )
#
#
# Email not displaying correctly? [View in browser]( )
#
# [Sent with MailGet]( )
# To view this mail in a browser, copy http://links.mail6.jabong.com/servlet/=
# MailView?ms=3DNTczMjIzMzAS1&r=3DMzUyNjk1NDYwMjM0S0&j=3DMTQ4MDkwNDUzMAS2&mt=
# =3D1&rt=3D0 into your browser.
# Download App:=09=09=09=09=09=09=C2=A0=09=09=09=09=09=09
#  http://links.mail6.jabong.com/ctt?kn=3D16&ms=3DNTczMjIzMzAS1&r=3DMzUyNjk1N=
# DYwMjM0S0&b=3D2&j=3DMTQ4MDkwNDUzMAS2&mt=3D1&rt=3D0 =09=09=09=09=09=09=C2=A0=
# =09=09=09=09=09=09
#  http://links.mail6.jabong.com/ctt?kn=3D6&ms=3DNTczMjIzMzAS1&r=3DMzUyNjk1ND=
# YwMjM0S0&b=3D2&j=3DMTQ4MDkwNDUzMAS2&mt=3D1&rt=3D0=20
#  http://links.mail6.jabong.com/ctt?kn=3D7&ms=3DNTczMjIzMzAS1&r=3DMzUyNjk1ND=
# YwMjM0S0&b=3D2&j=3DMTQ4MDkwNDUzMAS2&mt=3D1&rt=3D0 =09=09=C2=A0=09=09
# WOMEN=20
#  http://links.mail6.jabong.com/ctt?kn=3D24&ms=3DNTczMjIzMzAS1&r=3DMzUyNjk1N=
# DYwMjM0S0&b=3D2&j=3DMTQ4MDkwNDUzMAS2&mt=3D1&rt=3D0=20
# MEN=20
#  http://links.mail6.jabong.com/ctt?kn=3D14&ms=3DNTczMjIzMzAS1&r=3DMzUyNjk1N=
# DYwMjM0S0&b=3D2&j=3DMTQ4MDkwNDUzMAS2&mt=3D1&rt=3D0=20
# KIDS=20
#  http://links.mail6.jabong.com/ctt?kn=3D17&ms=3DNTczMjIzMzAS1&r=3DMzUyNjk1N=
# DYwMjM0S0&b=3D2&j=3DMTQ4MDkwNDUzMAS2&mt=3D1&rt=3D0=20
# ACCESSORIES=20
#  http://links.mail6.jabong.com/ctt?kn=3D22&ms=3DNTczMjIzMzAS1&r=3DMzUyNjk1N=
# DYwMjM0S0&b=3D2&j=3DMTQ4MDkwNDUzMAS2&mt=3D1&rt=3D0=20
# SPORTS=20
#  http://links.mail6.jabong.com/ctt?kn=3D8&ms=3DNTczMjIzMzAS1&r=3DMzUyNjk1ND=
# YwMjM0S0&b=3D2&j=3DMTQ4MDkwNDUzMAS2&mt=3D1&rt=3D0=20
# SALE http://links.mail6.jabong.com/ctt?kn=3D19&ms=3DNTczMjIzMzAS1&r=3DMzUyN=
# jk1NDYwMjM0S0&b=3D2&j=3DMTQ4MDkwNDUzMAS2&mt=3D1&rt=3D0=20
# THE JUICE=20
#  http://links.mail6.jabong.com/ctt?kn=3D11&ms=3DNTczMjIzMzAS1&r=3DMzUyNjk1N=
# DYwMjM0S0&b=3D2&j=3DMTQ4MDkwNDUzMAS2&mt=3D1&rt=3D0 =09=09
#  http://links.mail6.jabong.com/ctt?kn=3D9&ms=3DNTczMjIzMzAS1&r=3DMzUyNjk1ND=
# YwMjM0S0&b=3D2&j=3DMTQ4MDkwNDUzMAS2&mt=3D1&rt=3D0=20
#  http://links.mail6.jabong.com/ctt?kn=3D10&ms=3DNTczMjIzMzAS1&r=3DMzUyNjk1N=
# DYwMjM0S0&b=3D2&j=3DMTQ4MDkwNDUzMAS2&mt=3D1&rt=3D0=20
#  http://links.mail6.jabong.com/ctt?kn=3D3&ms=3DNTczMjIzMzAS1&r=3DMzUyNjk1ND=
# YwMjM0S0&b=3D2&j=3DMTQ4MDkwNDUzMAS2&mt=3D1&rt=3D0=20
#  http://links.mail6.jabong.com/ctt?kn=3D2&ms=3DNTczMjIzMzAS1&r=3DMzUyNjk1ND=
# YwMjM0S0&b=3D2&j=3DMTQ4MDkwNDUzMAS2&mt=3D1&rt=3D0 =09=09=09=09=09=C2=A0=09=
# =09=09=09=09
#
# You are recieving this email because you subscribed for our newsletters.
# To unsubscribe Click Here=20
#  http://links.mail6.jabong.com/ctt?kn=3D20&ms=3DNTczMjIzMzAS1&r=3DMzUyNjk1N=
# DYwMjM0S0&b=3D2&j=3DMTQ4MDkwNDUzMAS2&mt=3D1&rt=3D0=20
#
#
# <!DOCTYPE HTML>
# <html>
#   <head>
#     <META http-equiv=3D"Content-Type" content=3D"text/html; charset=3Dutf-8=
# ">
#     <meta name=3D"viewport" content=3D"width=3Ddevice-width, initial-scale=
# =3D1.0">
#     <title>Untitled Document</title>
#   </head>
#   <body style=3D"margin:0 auto;padding:0; max-width:400px; font-family:Open=
#  Sans, Helvetica, Arial, sans-serif; color:#000;">
#     <div  style=3D" padding: 10px; background: #fafbfb;">=20
#       <div style=3D"background:#fff;">
#         <div style=3D"overflow:hidden;">
#    <div style=3D"float:left; text-align:left;padding:50px 15px">
#       <img src=3D"http://assets.paytm.com/images/paytm-logo.png" style=3D"w=
# idth:75px;" />
#    </div>=20
#    <div style=3D"float:right; text-align:right; width:120px;">
#       <img src=3D"https://assetscdn.paytm.com/images/catalog/wallet/Notify/=
# corner_right.png" style=3D"width:120px;">
#    </div>
# </div>
# =20=20=20=20=20=20=20=20
#         <div style=3D"margin: 0 15px">
#           <div style=3D" margin:0 auto; overflow:hidden;">
# =20=20=20=20=20=20=20=20=20=20=20=20
#             <h1 style=3D"font-size:20px;font-weight:700; margin-bottom:10px=
# ;">Mobile Recharge Failed</h1>
#             <div style=3D"font-size:31px; margin-bottom: 30px;">
#               &#8377; <span style=3D"font-weight:700">13</span>
#               <span style=3D"padding-left:10px">
#                 <img src=3D"http://paytmimg.s3.amazonaws.com/games/fail-cro=
# ss/fail-cross%403x.png" width=3D"25px" height=3D"25px" style=3D"padding-top=
# :2px"/>
#               </span>
#             </div>
#             <div style=3D"font-size:15px;">
# =20=20=20=20=20=20=20=20=20=20=20=20=20=20
#               <div style=3D"overflow: hidden;">
#                 <div style=3D"font-size: 15px; width:77%; font-weight: 600;=
#  display: inline-block;">
#                   <div style=3D"font-size: 12px; color: #999; padding-botto=
# m: 6px; font-weight: normal">For</div>
#                   BSNL Mobile Number
#                   <div style=3D"padding-top: 6px;"> 9430233354</div>
#                 </div>
#                 <div style=3D"width:20%; vertical-align: bottom; display: i=
# nline-block;">
#                   <div style=3D"float:right;  border:1px solid #CCC; border=
# -radius:50px;width: 60px; height: 60px; text-align:center;">
#                     <img src=3D"https://catalog.paytm.com/images/2/8.jpg" s=
# tyle=3D"width:70%; padding-top: 8px;">
#                   </div>
#                 </div>
#               </div>
# =20=20=20=20=20=20=20=20=20=20=20=20=20=20
#               <div style=3D"font-size:12px; color:#999; overflow:hidden; pa=
# dding: 30px 0 20px; border-bottom: 1px solid #f4f4f4;">04:33 PM, Sep 7, 2018
#                   <span style=3D"display: block; padding-top: 5px;">Order I=
# D 5977191909</span>
#               </div>
# =20=20=20=20=20=20=20=20=20=20=20=20=20=20
#                 <div style=3D"padding: 20px 0; font-weight: 600;">Your Refu=
# nd Status</div>
# =20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20
#                   <div style=3D"padding-bottom: 20px; overflow: hidden;font=
# -size: 15px;">
# =20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20
#                       =E2=82=B9 <span style=3D"font-weight: 600">13</span> =
# has been refunded to your Paytm Wallet linked to <span style=3D"font-weight=
# : 600">8804673335</span>=20
# =20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20
#                   </div>
# =20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20
# =20=20=20=20=20=20=20=20=20=20=20=20=20=20
#             </div>
#           </div>
#         </div>
#         <div style=3D"border-top: solid 1px #f4f4f4; padding: 0 10px;">
#             <div style=3D"padding: 20px 5px;">
#               <a href=3D"https://paytm.com/myorders/5977191909" target=3D"_=
# blank" style=3D"text-decoration:none; text-align:left; color:#222; font-siz=
# e:15px;">
#                 View more details
#                 <span style=3D"float: right">&#10095;</span>
#             </div>
#             <div style=3D"padding: 20px 5px; border-top: solid 1px #f3f7f8;=
# ">
#               <a href=3D"http://m.p-y.tm/care" target=3D"_blank" style=3D"t=
# ext-decoration:none; text-align:left; color:#222; font-size:15px;">
#                 Need help?
#                 <span style=3D"float: right">&#10095;</span>
#             </div>
#           </div>
#       </div>=20
#     </div>
#     <div align=3D"center" max-width=3D"400px" bgcolor=3D"#fafbfb" style=3D"=
# padding-bottom:0px;">
#         <a href=3D"http://m.p-y.tm/tr23" style=3D"color:#666666;text-decora=
# tion: none;" target=3D"_blank">
#           <img src=3D"https://s3-ap-southeast-1.amazonaws.com/assets.paytm.=
# com/promotion/Ash1/Transaction.jpg" width=3D"100%">
#         </a>
#       </div>
#       <div style=3D"text-align:center; padding: 10px 10px 15px 10px; color:=
# #666666;line-height:16px; font-size: 11px;letter-spacing:0.2px;">
#         Please do not share your Paytm password, Paytm passcode, OTP, Credi=
# t/Debit card number and CVV or any other confidential information with anyo=
# ne even if he/she claims to be from Paytm. We advise our customers to compl=
# etely ignore such communications.
#       </div>=20=20=20=20=20=20=20
#       <div style=3D"background:#00B0DE; height:7px;"></div>
#       <div style=3D"background:#0E2855; height:7px;"></div>
#   </body>
# </html>=
# To view this mail in a browser, copy http://links.mail6.jabong.com/servlet/=
# MailView?ms=3DNTczMjcyODYS1&r=3DMzUyNjk1NDYwMjM0S0&j=3DMTQ4MTAxNTU5MwS2&mt=
# =3D1&rt=3D0 into your browser.
# Download App:=09=09=09=09=09=09=C2=A0=09=09=09=09=09=09
#  http://links.mail6.jabong.com/ctt?kn=3D16&ms=3DNTczMjcyODYS1&r=3DMzUyNjk1N=
# DYwMjM0S0&b=3D2&j=3DMTQ4MTAxNTU5MwS2&mt=3D1&rt=3D0 =09=09=09=09=09=09=C2=A0=
# =09=09=09=09=09=09
#  http://links.mail6.jabong.com/ctt?kn=3D6&ms=3DNTczMjcyODYS1&r=3DMzUyNjk1ND=
# YwMjM0S0&b=3D2&j=3DMTQ4MTAxNTU5MwS2&mt=3D1&rt=3D0=20
#  http://links.mail6.jabong.com/ctt?kn=3D7&ms=3DNTczMjcyODYS1&r=3DMzUyNjk1ND=
# YwMjM0S0&b=3D2&j=3DMTQ4MTAxNTU5MwS2&mt=3D1&rt=3D
ms=3DNTczNDA3MTgS1&r=3DMzUyNjk1ND=
# YwMjM0S0&b=3D2&j=3DMTQ4MTM4ODUyMgS2&mt=3D1&rt=3D0=20
# SALE http://links.mail6.jabong.com/ctt?kn=3D19&ms=3DNTczNDA3MTgS1&r=3DMzUyN=
# jk1NDYwMjM0S0&b=3D2&j=3DMTQ4MTM4ODUyMgS2&mt=3D1&rt=3D0=20
# THE JUICE=20
#  http://links.mail6.jabong.com/ctt?kn=3D11&ms=3DNTczNDA3MTgS1&r=3DMzUyNjk1N=
# DYwMjM0S0&b=3D2&j=3DMTQ4MTM4ODUyMgS2&mt=3D1&rt=3D0 =09=09
#  http://links.mail6.jabong.com/ctt?kn=3D9&ms=3DNTczNDA3MTgS1&r=3DMzUyNjk1ND=
# YwMjM0S0&b=3D2&j=3DMTQ4MTM4ODUyMgS2&mt=3D1&rt=3D0=20
#  http://links.mail6.jabong.com/ctt?kn=3D10&ms=3DNTczNDA3MTgS1&r=3DMzUyNjk1N=
# DYwMjM0S0&b=3D2&j=3DMTQ4MTM4ODUyMgS2&mt=3D1&rt=3D0=20
#  http://links.mail6.jabong.com/ctt?kn=3D3&ms=3DNTczNDA3MTgS1&r=3DMzUyNjk1ND=
# YwMjM0S0&b=3D2&j=3DMTQ4MTM4ODUyMgS2&mt=3D1&rt=3D0=20
#  http://links.mail6.jabong.com/ctt?kn=3D2&ms=3DNTczNDA3MTgS1&r=3DMzUyNjk1ND=
# YwMjM0S0&b=3D2&j=3DMTQ4MTM4ODUyMgS2&mt=3D1&rt=3D0 =09=09=09=09=09=C2=A0=09=
# =09=09=09=09
#
# You are recieving this email because you subscribed for our newsletters.
# To unsubscribe Click Here=20
#  http://links.mail6.jabong.com/ui/modules/display/optOut.jsp?&m=3D57340718&=
# r=3DMzUyNjk1NDYwMjM0S0&j=3DMTQ4MTM4ODUyMgS2&mt=3D1&rt=3D0=20
#
#
# *NOTICE*
#
#
#
#
#
# All the students of BCA, BBA, MCA & M.Sc(IS) are here by informed that the 1
# st internal examination of Odd Semester 2018 will be held on 18th, 19th & 20
# th September, 2018.
#
#
# The routine for the examination is attached herewith.
#
#
#
#
#
#
#
#
#
# By order
#
# Examination Cell
#
# Techno India Hooghly
#
# Dt.: 04/09/2018
#
#
#
#
# --
# Web Admin
# Techno India Hooghly
# ----------------------------------------------------------------------------
# Phone:      (033) 2680 2389 / 6565
# Website:   www.technoindiahooghly.org
# ----------------------------------------------------------------------------
#
# --
# --
# Have a bright future and a prosperous life.
# ----------------------------------------------------------------------------------------------------------------------
# You received this message because you are subscribed to the Google
# Groups of "Techno India Hooghly"
# To post to this group, send email to technoindiahooghly@googlegroups.com
# To unsubscribe from this group, send email to:
# technoindiahooghly+unsubscribe@googlegroups.com
#
# ---
# You received this message because you are subscribed to the Google Groups "Techno India Hooghly" group.
# To unsubscribe from this group and stop receiving emails from it, send an email to technoindiahooghly+unsubscribe@googlegroups.com.
# For more options, visit https://groups.google.com/d/optout.
#
# Indeed Job Alert
# typing jobs in Hugli, West Bengal
#
# 1 new vacancy
# See matching results on Indeed: https://www.indeed.co.in/jobs?q=typing&hl=en&from=ja&l=Hooghly-Chinsurah%2C+West+Bengal&radius=25&alid=5a896189e4b09960710bc09e&tmtk=1cn9ahjlh3936ecd&utm_source=jobseeker_emails&utm_medium=email&utm_campaign=job_alerts&of=1&fr=t
#
#
# Customer Service Representative
# scope infotech - Noapara, Kolkata, West Bengal
# Assist In Typing Documents/letters For Functional Heads. We Are Seeking A Skilled And Self-motivated Front Office Worker To Join Our Growing Team....
# Indeed - 13-Sep
# https://www.indeed.co.in/rc/clk/dl?jk=feff18ed125c9fd3&from=ja&qd=RnZhMybXSk4M3QtTVGXWoUDZM7-Fq4VfBUKFXg1awEnZD2JiZdfDjqd-7q1lq4igK5cZBBayFzoH71t1EbBiZphj_bBR8UkXLO4xhK6bvwqnWPlH9_RyejkFn3M3AMXk&rd=XOl8d0_ghx9bSNbodjJ9PF_MKnaSAFGAsD6kfERFt3g&tk=1cn9ahjlh3936ecd&alid=5a896189e4b09960710bc09e
#
#
# Edit this Job Alert: https://subscriptions.indeed.com/update/5a896189e4b09960710bc09e?token=CkAB_uNtrg2NJp--98NfWEpZM2gfRcnUtpGIH4UGpR4iDsyQEu91as7uSBYteU7a5uDvDVrFNoN2wP5eTjIerXhsEiBrk4LSxnoCaTMRu1M4JsTi0mJGLU1gylsU2G4c2PK5OhoQWIdOiuOYeFjnAFUEvWsLXw%3D%3D&co=IN&hl=en&tmtk=1cn9ahjlh3936ecd&from=jaEditAlert
#
# Cancel this Job Alert: https://subscriptions.indeed.com/alerts/cancel?token=C
alid=5a896189e4b09960710bc09e
#
#
# Edit this Job Alert: https://subscriptions.indeed.com/update/5a896189e4b09960710bc09e?token=CkDhVpzlerdOfrQ92dT0KbvFV7ze9eN0vDAnHVysZiHnBAaqL4Hib4rGaEqnWTNkP3VpqeEGZCbIqeOReWJ7DaKdEiAL_4D6RK2oXWTYZnvXAK0X6bL4bmMByg8psoOMzcRBHhoQNJvGUR4V_Ef-2pU9D0g5vg%3D%3D&co=IN&hl=en&tmtk=1cnefb067384j8fj&from=jaEditAlert
#
# Cancel this Job Alert: https://subscriptions.indeed.com/alerts/cancel?token=CkDhVpzlerdOfrQ92dT0KbvFV7ze9eN0vDAnHVysZiHnBAaqL4Hib4rGaEqnWTNkP3VpqeEGZCbIqeOReWJ7DaKdEiAL_4D6RK2oXWTYZnvXAK0X6bL4bmMByg8psoOMzcRBHhoQNJvGUR4V_Ef-2pU9D0g5vg%3D%3D&co=IN&hl=en&tmtk=1cnefb067384j8fj&subId=5a896189e4b09960710bc09e&rgtk=1cnefh67327r8en7&from=ja
#
# Indeed - one search. all jobs. | Indeed Ireland Operations Limited, 124 St. Stephen's Green, Dublin 2, Ireland
#
# Dear Cardholder,
#
# OTP to Register/Reset Password for Online Transactions on your Andhra Bank Card number ending with 4148 is 824274.This is valid for the next 60 min.Dt:16-09-18 01:01
#
# Thanking You,
# Andhra Bank Team
# Dear Customer,
# POS transaction of Rs.320.00 is done on Card XX4148 on 15-09-2018. A/c Balance is Rs. 5142.85.
# If you have any queries about this transaction, please call Toll Free Number 1800-425-1515.
#
# Sincerely,
# Andhra Bank.
# Note: As per RBI mandate debit cards issued after 31-11-13 are valid for domestic TXN only.For international use,Plz apply for chip debit card at branch with required limits.
#
# This is an automated e-mail from an unattended mailbox. Please do not reply to this email.
#
# Stories from your activity
#
# -----
#
#
# Question: How does garbage collection work in the JVM?
#
# Answer from Akash Jain
#
# Important points about Garbage collection=20
# 1) Objects are created on heap in Java irrespective of there scope e.g. loc=
# al or member variable. while its worth noting that class=20
# Read More: https://www.quora.com/How-does-garbage-collection-work-in-the-JV=
# M#ans14923809
# -----
# Question: Is it true that only 20 people in the world truly understand Java=
#  garbage collection?
#
# Answer from Dan Shappir
#
# Q: Is it true that only 20 people in the world truly understand Java garbag=
# e collection?
#
# It=E2=80=99s possible that only a few people in the world are intimately fa=
# miliar with the cu
# Read More: https://www.quora.com/Is-it-true-that-only-20-people-in-the-worl=
# d-truly-understand-Java-garbage-collection#ans71417921
# -----
# Question: Why are Java and Go garbage collected whereas Swift and Rust are =
# not?
#
# Answer from Michael Bach
#
# TL;DR answer:
#
# Different languages designed with very different purposes in mind.
#
# Java (over time) has grown mostly into a application server language. It pr=
# ovides very stron
# Read More: https://www.quora.com/Why-are-Java-and-Go-garbage-collected-wher=
# eas-Swift-and-Rust-are-not#ans57109034
# -----
# Question: How does the Java garbage collection algorithm work? How is the m=
# ark-and-sweep algorithm used?
#
# Answer from Sanjoy Das
#
# Answering your first question:
#
# Generational GC is faster because it only traces the young generation -- yo=
# u do not trace through objects in the old generation at all.  You ca
# Read More: https://www.quora.com/How-does-the-Java-garbage-collection-algor=
# ithm-work-How-is-the-mark-and-sweep-algorithm-used#ans12050519
# -----
# Question: What is the purpose of garbage collection in Java, and when is it=
#  used?
#
# Answer from William Ritson
#
# Every time you create an Object memory is allocated from your computers f t=
# o store that object. If you never got rid of these objects then your progra=
from=ja
#
# Indeed - one search. all jobs. | Indeed Ireland Operations Limited, 124 St. Stephen's Green, Dublin 2, Ireland
#
# [Click to Apply]( )
#
#
#
# [Click to Apply]( )
#
#
#
# [Click to Apply]( )
#
#
#
# [Click to Apply]( )
#
#
#
# [Click to Apply]( )
#
#
#
# [Click to Apply]( )
#
#
#
#
# []( )	[]( )	[]( )	[]( )
#
#
#
#
#
#
# If you are no longer interested, you can [ unsubscribe instantly]( )
#
# Email not displaying correctly? [View in browser]( )
#
# [Sent with MailGet]( )
# Dear Customer,
# POS transaction of Rs.1020.00 is done on Card XX4148 on 20-09-2018. A/c Balance is Rs. 2604.85.
# If you have any queries about this transaction, please call Toll Free Number 1800-425-1515.
#
# Sincerely,
# Andhra Bank.
# Note: As per RBI mandate debit cards issued after 31-11-13 are valid for domestic TXN only.For international use,Plz apply for chip debit card at branch with required limits.
#
# This is an automated e-mail from an unattended mailbox. Please do not reply to this email.
#
# Dear Customer,
# POS transaction of Rs.1020.00 is done on Card XX4148 on 20-09-2018. A/c Balance is Rs. 1584.85.
# If you have any queries about this transaction, please call Toll Free Number 1800-425-1515.
#
# Sincerely,
# Andhra Bank.
# Note: As per RBI mandate debit cards issued after 31-11-13 are valid for domestic TXN only.For international use,Plz apply for chip debit card at branch with required limits.
#
# This is an automated e-mail from an unattended mailbox. Please do not reply to this email.
#
# Dear Customer,
# POS transaction of Rs.1020.00 is done on Card XX4148 on 20-09-2018. A/c Balance is Rs. 564.85.
# If you have any queries about this transaction, please call Toll Free Number 1800-425-1515.
#
# Sincerely,
# Andhra Bank.
# Note: As per RBI mandate debit cards issued after 31-11-13 are valid for domestic TXN only.For international use,Plz apply for chip debit card at branch with required limits.
#
# This is an automated e-mail from an unattended mailbox. Please do not reply to this email.
#
# Indeed Job Alert
# typing jobs in Hugli, West Bengal
#
# 1 new vacancy
# See matching results on Indeed: https://www.indeed.co.in/jobs?q=typing&hl=en&from=ja&l=Hooghly-Chinsurah%2C+West+Bengal&radius=25&alid=5a896189e4b09960710bc09e&tmtk=1cnrbajo736ua80c&utm_source=jobseeker_emails&utm_medium=email&utm_campaign=job_alerts&of=1&fr=t
#
#
# BACK-OFFICE ASSIST
# Aquad Yamaha - Kamarhati, Kolkata, West Bengal
# Office Experience - General, Scheduling, Telephone Skills, Typing, Documentation Skills, Meeting Planning, Verbal Communication, Written Communication,...
# Aquad Yamaha - 19-Sep
# https://www.indeed.co.in/rc/clk/dl?jk=7a25c461a0e5be46&from=ja&qd=RnZhMybXSk4M3QtTVGXWoUDZM7-Fq4VfBUKFXg1awEnZD2JiZdfDjqd-7q1lq4igK5cZBBayFzoH71t1EbBiZnk40i3u6VtLNwFTSvv0iR9s6_F8jjkjDvokXcC8sutV&rd=fqiY8RJDvosIMzxD6v1HZV_MKnaSAFGAsD6kfERFt3g&tk=1cnrbajo736ua80c&alid=5a896189e4b09960710bc09e
#
#
# Edit this Job Alert: https://subscriptions.indeed.com/update/5a896189e4b09960710bc09e?token=CkBdas8CQaWz5aSI1iiBgfLYv_ApJD3m0PiJ1uPj3_G-Ml88wByfUIJl-Jlk-j32cyepPaQMLzZ0mYL5usz8I5wPEiDHzngioAw50vmYiSRvUC7fD-Jm_SvkK6jIInOb80B5yhoQQ2pLasmt24WRfdTrqBskNQ%3D%3D&co=IN&hl=en&tmtk=1cnrbajo736ua80c&from=jaEditAlert
#
# Cancel this Job Alert: https://subscriptions.indeed.com/alerts/cancel?token=CkBdas8CQaWz5aSI1iiBgfLYv_ApJD3m0PiJ1uPj3_G-Ml88wByfUIJl-Jlk-j32cyepPaQMLzZ0mYL5usz8I5wPEiDHzngioAw50vmYiSRvUC7fD-Jm_SvkK6jIInOb80B5yhoQQ2pLasmt24WRfdTrqBskNQ%3D%3D&co=IN&hl=en&tmtk=1cnrbajo736ua80c&subId=5a896189e4b09960710bc09e&rgtk=1cnrbmjjs3crs803&from=ja
#
# Indeed - one search. all jobs. | Indeed Ireland Operations Limited, 124 St. Stephen's Green, Dublin 2, Ireland
# Your email client cannot read this email.
# To view it online, please go here:
# http://em.internshala.com/display.php?M=94641649&C=a8a30a16505272b71dad67cd1ce477d3&S=14425&L=5973&N=9889
#
#
# To stop receiving these
# emails:http://em.internshala.com/unsubscribe.php?M=94641649&C=a8a30a16505272b71dad67cd1ce477d3&L=5973&N=14425
#
# 20 Sep 2018 9:35 PM ₹ 91 OSN1129028795 Thanks for traveling with us, Ashish Kumar Ride Details Dilip Kr Share - White Indica 9:35 PM Dum Dum Park Concrete Bridge, Over Bagjola Canal Towards, Kazi Nazrul Avenue, Dum Dum Park, South Dum Dum, Kolkata 10:01 PM Dumdum Railway Station, Biswanath Colony Satpukur Kolkata West Bengal India Fare Details Base Fare ₹ 83.21 Taxes ₹ 6.32 Total Bill ₹ 91 You saved ₹57.0 on this ride with Ola Share. To download invoice or raise queries, find support for this booking. Payment olacabs olacabs olacabs olacabs olacabs olacabs Paid by Cash ₹90.00
#
# Indeed Job Alert
# typing jobs in Hugli, West Bengal
#
# 1 new vacancy
# See matching results on Indeed: https://www.indeed.co.in/jobs?q=typing&hl=en&from=ja&l=Hooghly-Chinsurah%2C+West+Bengal&radius=25&alid=5a896189e4b09960710bc09e&tmtk=1cnttnabd36ua804&utm_source=jobseeker_emails&utm_medium=email&utm_campaign=job_alerts&of=1&fr=t
#
#
# BACK-OFFICE ASSIST
# Aquad Yamaha - Kamarhati, Kolkata, West Bengal
# Office Experience - General, Scheduling, Telephone Skills, Typing, Documentation Skills, Meeting Planning, Verbal Communication, Written Communication,...
# Aquad Yamaha - 19-Sep
# https://www.indeed.co.in/rc/clk/dl?jk=7a25c461a0e5be46&from=ja&qd=RnZhMybXSk4M3QtTVGXWoUDZM7-Fq4VfBUKFXg1awEnZD2JiZdfDjqd-7q1lq4igK5cZBBayFzoH71t1EbBiZltJ88Qd01J9XeNvIqkzIha0X9tepoT7gncu-bQTZJu6&rd=fqiY8RJDvosIMzxD6v1HZV_MKnaSAFGAsD6kfERFt3g&tk=1cnttnabd36ua804&alid=5a896189e4b09960710bc09e
#
#
# Edit this Job Alert: https://subscriptions.indeed.com/update/5a896189e4b09960710bc09e?token=CkC6psfnanBVQTlZc5i_c5epBLp4xUAdJatpRIgCjWVn_s6-OvCdOJ7GOp2_IIm3eZpNGQ9DpsTcJwxVy4i0EkLDEiByz22exoBQ7z2Tujmj4QlnN1688XEAbjlBQmyCDYE4QhoQW0f_QS9iNwBHVRD9gbBHOQ%3D%3D&co=IN&hl=en&tmtk=1cnttnabd36ua804&from=jaEditAlert
#
# Cancel this Job Alert: https://subscriptions.indeed.com/alerts/cancel?token=CkC6psfnanBVQTlZc5i_c5epBLp4xUAdJatpRIgCjWVn_s6-OvCdOJ7GOp2_IIm3eZpNGQ9DpsTcJwxVy4i0EkLDEiByz22exoBQ7z2Tujmj4QlnN1688XEAbjlBQmyCDYE4QhoQW0f_QS9iNwBHVRD9gbBHOQ%3D%3D&co=IN&hl=en&tmtk=1cnttnabd36ua804&subId=5a896189e4b09960710bc09e&rgtk=1cnttnjvh3cso805&from=ja
#
# Indeed - one search. all jobs. | Indeed Ireland Operations Limited, 124 St. Stephen's Green, Dublin 2, Ireland
#
# <!DOCTYPE HTML>
# <html>
#   <head>
#     <META http-equiv=3D"Content-Type" content=3D"text/html; charset=3Dutf-8=
# ">
#     <meta name=3D"viewport" content=3D"width=3Ddevice-width, initial-scale=
# =3D1.0">
#     <title>Untitled Document</title>
#   </head>
#   <body style=3D"margin:0 auto;padding:0; max-width:400px; font-family:Open=
#  Sans, Helvetica, Arial, sans-serif; color:#000;">
#     <div  style=3D" padding: 10px; background: #fafbfb;">=20
#       <div style=3D"background:#fff;">
#         <div style=3D"overflow:hidden;">
#    <div style=3D"float:left; text-align:left;padding:50px 15px">
#       <img src=3D"http://assets.paytm.com/images/paytm-logo.png" style=3D"w=
# idth:75px;" />
#    </div>=20
#    <div style=3D"float:right; text-align:right; width:120px;">
#       <img src=3D"https://assetscdn.paytm.com/images/catalog/wallet/Notify/=
# corner_right.png" style=3D"width:120px;">
#    </div>
# </div>
# =20=20=20=20=20=20=20=20
#         <div style=3D"margin: 0 15px 10px">
#           <div style=3D" margin:0 auto; overflow:hidden;">
# =20=20=20=20=20=20=20=20=20=20=20=20
#             <h1 style=3D"font-size:20px;font-weight:700; margin-bottom:10px=
# ;">Mobile Recharge Successful</h1>
#             <div style=3D"font-size:31px; margin-bottom: 30px;">
#               &#8377; <span style=3D"font-weight:700">10</span>
#               <span style=3D"padding-left:10px">
#                 <img src=3D"https://assetscdn.paytm.com/images/catalog/wall=
# et/Notify/tick.png" width=3D"25px" height=3D"25px" style=3D"padding-top:2px=
# "/>
#               </span>
#             </div>
#             <div style=3D"font-size:15px;">
# =20=20=20=20=20=20=20=20=20=20=20=20=20=20
#               <div style=3D"overflow: hidden;">
#                 <div style=3D"font-size: 15px; width:77%; font-weight: 600;=
#  display: inline-block;">
#                   <div style=3D"font-size: 12px; color: #999; padding-botto=
# m: 6px; font-weight: normal">For</div>
#                   BSNL Mobile Number
#                   <div style=3D"padding-top: 6px;"> 9430233354</div>
#                 </div>
#                 <div style=3D"width:20%; vertical-align: bottom; display: i=
# nline-block;">
#                   <div style=3D"float:right;  border:1px solid #CCC; border=
# -radius:50px;width: 60px; height: 60px; text-align:center;">
#                     <img src=3D"https://catalog.paytm.com/images/2/7.jpg" s=
# tyle=3D"width:70%; padding-top: 8px;">
#                   </div>
#                 </div>
#               </div>
# =20=20=20=20=20=20=20=20=20=20=20=20=20=20
#               <div style=3D"padding-top: 5%; overflow: hidden;">
# =20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20
#                 <div style=3D"font-size: 12px; color: #999;">Paid From</div>
#                 <div style=3D"float:left; font-size: 15px; width:77%;">
# =20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20
#                         <div style=3D"display: block; font-weight:700; padd=
# ing-top: 6px;">
#                             ASHISH KUMAR's Wallet linked to 8804673335
#                         </div>
# =20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20=20
#                 </div>
#               </div>
# =20=20=20=20=20=20=20=20=20=20=20=20=20=20
#             </div>
#           </div>
#           <div style=3D"margin: 30px 0 20px; font-size:12px; color:#999;">0=
# 9:21 AM, Sep 22, 2018
#               <span style=3D"display: block; padding-top: 5px;">Order ID 60=
# 84081315</span>
#           </div>
# =20=20=20=20=20=20=20=20=20=20
#             <div style=3D"padding: 20px 0; border-top: solid 1px #f4f4f4; f=
# ont-size: 14px; color: #444">
#               If you have queries regarding your Recharge, please contact B=
# SNL customer care with Operator Ref No. <span style=3D"font-weight: 700;">2=
# 554586885</span>
#             </div>
# =20=20=20=20=20=20=20=20=20=20
#         </div>
#         <div style=3D"border-top: solid 1px #f4f4f4; padding: 0 10px;">
#             <div style=3D"padding: 20px 5px;">
#               <a href=3D"https://paytm.com/myorders/6084081315" target=3D"_=
# blank" style=3D"text-decoration:none; text-align:left; color:#222; font-siz=
# e:15px;">
#                 View more details
#                 <span style=3D"float: right">&#10095;</span>
#             </div>
#             <div style=3D"padding: 20px 5px; border-top: solid 1px #f3f7f8;=
# ">
#               <a href=3D"http://m.p-y.tm/care" target=3D"_blank" style=3D"t=
# ext-decoration:none; text-align:left; color:#222; font-size:15px;">
#                 Need help?
#                 <span style=3D"float: right">&#10095;</span>
#             </div>
#           </div>
#       </div>=20
#     </div>
#     <div align=3D"center" max-width=3D"400px" bgcolor=3D"#fafbfb" style=3D"=
# padding-bottom:0px;">
#         <a href=3D"http://pytm.ml/mallmps" style=3D"color:#666666;text-deco=
# ration: none;" target=3D"_blank">
#           <img src=3D"https://s3-ap-southeast-1.amazonaws.com/assets.paytm.=
# com/promotion/Ashish/Transaction.jpg" width=3D"100%">
#         </a>
#       </div>
#       <div style=3D"text-align:center; padding: 10px 10px 15px 10px; color:=
# #666666;line-height:16px; font-size: 11px;letter-spacing:0.2px;">
#         Please do not share your Paytm password, Paytm passcode, OTP, Credi=
# t/Debit card number and CVV or any other confidential information with anyo=
# ne even if he/she claims to be from Paytm. We advise our customers to compl=
# etely ignore such communications.
#       </div>=20=20=20=20=20=20=20
#       <div style=3D"background:#00B0DE; height:7px;"></div>
#       <div style=3D"background:#0E2855; height:7px;"></div>
#   </body>
# </html>=
#
# *NOTICE*
#
# Due to some unavoidable circumstances the Seminar on The Basics of MBA/PGDM
# Prospects and Their Role in Choosing a Right Career which was to be held on
# 26th September has been rescheduled to 28th September, 2018 at 12:40AM. All
# ...
# =E0=A5=80=E0=A4=A4 =E0=A4=94=E0=A4=B0
# =E0=A4=95=E0=A4=A0=E0=A4=BF=E0=A4=A8=E0=A4=BE=E0=A4=88 =E0=A4=AA=E0=A5=
# =82=E0=A4=B0=E0=A5=8D=E0=A4=A3 =E0=A4=9A=E0=A4=B2 =E0=A4=B0=E0=A4=B9 =
# =E0=A4=B9=E0=A5=88?
# =E0=A4=95=E0=A5=8D=E0=A4=AF=E0=A4=BE =E0=A4=86=E0=A4=AA =E0=A4=96=E0=A5=
# =81=E0=A4=A6 =E0=A4=95=E0=A5=8B =E0=A4=B8=E0=A4=AE=E0=A4=B8=E0=A5=8D=
# =E0=A4=AF=E0=A4=BE=E0=A4=93=E0=A4=82 =E0=A4=B8=E0=A5=87
# =E0=A4=98=E0=A4=BF=E0=A4=B0=E0=A4=BE =E0=A4=B9=E0=A5=81=E0=A4=86 =E0=A4=
# =AA=E0=A4=BE=E0=A4=A4=E0=A5=87=E0=A4=82 =E0=A4=B9=E0=A5=88=E0=A4=82?
# =E0=A4=85=E0=A4=97=E0=A4=B0 =E0=A4=86=E0=A4=AA=E0=A4=95=E0=A4=BE =E0=A4=
# =9C=E0=A4=B5=E0=A4=BE=E0=A4=AC =E0=A4=B9=E0=A4=BE=E0=A4=81 =E0=A4=B9=
# =E0=A5=88 - =E0=A4=A4=E0=A5=8B =E0=A4=AF=E0=A4=B9
# 3 =E0=A4=AF=E0=A4=A8=E0=A5=8D=E0=A4=A4=E0=A5=8D=E0=A4=B0 =E0=A4=85=E0=A4=
# =AA=E0=A4=A8=E0=A5=87 =E0=A4=98=E0=A4=B0 =E0=A4=AE=E0=A5=87=E0=A4=82 =
# =E0=A4=85=E0=A4=B5=E0=A4=B6=E0=A5=8D=E0=A4=AF
# =E0=A4=B0=E0=A4=96=E0=A5=87=E0=A4=82 |
# =E0=A4=A8=E0=A5=9B=E0=A4=B0 =E0=A4=B8=E0=A5=81=E0=A4=B0=E0=A4=95=E0=A5=
# =8D=E0=A4=B7=E0=A4=BE =E0=A4=95=E0=A4=B5=E0=A4=9A =E0=A4=95=E0=A4=BE =
# =E0=A4=AF=E0=A4=B9
# =E0=A4=A4=E0=A5=8D=E0=A4=B0=E0=A4=BF=E0=A4=95=E0=A5=8B=E0=A4=A3=E0=A5=80=
# =E0=A4=AF =E0=A4=AE=E0=A5=87=E0=A4=B2 =E0=A4=86=E0=A4=AA=E0=A4=95=E0=A4=
# =BE =E0=A4=AC=E0=A4=9A=E0=A4=BE=E0=A4=B5
# =E0=A4=95=E0=A4=B0=E0=A5=87=E0=A4=97=E0=A4=BE |
# =E0=A4=86=E0=A4=9C =E0=A4=B9=E0=A5=80 =E0=A4=85=E0=A4=AA=E0=A4=A8=E0=A5=
# =87 =E0=A4=98=E0=A4=B0 =E0=A4=B2=E0=A4=BE=E0=A4=8F=E0=A4=82=E2=80=8B=
# =E2=80=8B=E2=80=8B=E2=80=8B=E2=80=8B - Buy
# Now
# _=E0=A4=AC=E0=A5=81=E0=A4=B0=E0=A5=80 =E0=A4=A8=E0=A5=9B=E0=A4=B0 =E0=A4=
# =B8=E0=A5=87 =E0=A4=AC=E0=A4=9A=E0=A4=A8=E0=A5=87 =E0=A4=95=E0=A5=87 =
# =E0=A4=85=E0=A4=A8=E0=A5=8D=E0=A4=AF
# =E0=A4=89=E0=A4=AA=E0=A4=BE=E0=A4=8F _
# http://m.casaconsultant.com/wiz/index.php/campaigns/cn601e267f047/track-url=
# /fz18321b073bd/afb4bc94ba8f89bd9e679a47b40558f4436bb3ee
# - =E0=A4=AF=E0=A4=B9=E0=A4=BE=E0=A4=81 =E0=A4=A6=E0=A5=87=E0=A4=96=E0=A5=
# =87=E0=A4=82
# Bank Nifty comparatively remained range bound but managed to extend
# its gains towards 27,400 zones. It formed a Bullish Candle and entered
# the crucial hurdle zone of 27,500-27,750. related news RBI cuts repo
# rate by 25 bps, raises hopes of further cuts; changes stance to
# 'neutral' EXCLUSIVE: Bajaj Auto to roll out Husqvarna before
# September, Triumph takes a back seat According to Pivot charts, the
# key support level is placed at 10,992.6, followed by 10,922.7. If the
# index starts moving upward, key resistance levels to watch out are
# 11,102.5 and then 11,142.5. Traders are advised to remain long with a
# stop below 10,980 levels on a closing basis and look for a bigger
# target placed around 11,400 levels, experts said. The Nifty Bank index
# closed at 27,402.3. The important Pivot level, which will act as
# crucial support for the index, is placed at 27,321.36, followed by
# 27,240.43. On the upside, key resistance levels are placed at
# 27,455.96, followed by 27,509.63. In an interview to CNBC-TV18, top
# market experts recommend which stocks to bet on for good returns:
# Ashwani Gujral of ashwanigujral.com Buy Axis Bank with a stop loss of
# Rs 720, target of Rs 745 Buy Hexaware Tech with a stop loss of Rs 355,
# target of Rs 372 Buy Maruti Suzuki with a stop loss of Rs 7150, target
# of Rs 7300 Buy Bajaj Finance with a stop loss of Rs 2690, target of Rs
# 2760 Buy Tata Steel with a stop loss of Rs 480, target of Rs 510
# Mitessh Thakkar of mitesshthakkar.com Buy CESC with a stop loss of Rs
# 716 and target of Rs 755 Buy Cipla with a stop loss of Rs 527 and
# target of Rs 548 Buy Hindalco Industries with a stop loss of Rs 207
# and target of Rs 219 Buy PNB Housing Finance with a stop loss of Rs
# 918 and target of Rs 995 Prakash Gaba of prakashgaba.com Buy Bajaj
# Finance with target at Rs 2750-2800 and stop loss at Rs 2650 Buy
# Grasim Industries with target at Rs 775 and stop loss at Rs 716 Buy
# Hindalco Industries with target at Rs 220 and stop loss at Rs 207 Buy
# State Bank of India with target at Rs 295 and stop loss at Rs 285
# =C2=A0
# Unsubscribe
# http://m.casaconsultant.com/wiz/index.php/campaigns/cn601e267f047/track-url=
# /fz18321b073bd/d32fd8c6289a905ae3d6435c436fd8f85276b0f4
# =C2=A0
#
#
# View Online
# http://m.casaconsultant.com/wiz/index.php/campaigns/qt509dv181895/track-url=
# /hp866jhxd7c12/88a0a031a69b4906c27efe3797830ccdc40f712b
# Canada/Australia Need Skilled ProfCanada Express and VIP Process - For
# First 25Canada Express and VIP Process - For First 25Canadaessionals -
# Check Your Eligibility.Canada Express and VIP Process - For First
# 25Canada Express and VIP Process - For First 25
# http://m.casaconsultant.com/wiz/index.php/campaigns/qt509dv181895/track-url=
# /hp866jhxd7c12/1d8adebfa40907cf40cb09cb479385e9748bff79
# With the monetary policy announcement out of the way, the focus of
# the markets will shift to how the Reserve Bank of India (RBI) is
# likely to react in future. The central bank has clearly said we should
# expect =E2=80=9Ccalibrated tightening=E2=80=9D from now on, the extent of
# tightening depending on the inflation numbers. Simply put, interest
# rates will go up in future, though not necessarily at every meeting.
# RBI has helpfully laid out a laundry list of risks at the end of its
# statement, which includes higher support prices for agriculture, oil
# prices, rising input costs and pricing power, fiscal slippage, et al.
# The monetary policy report (MPR) fleshes out some of these concerns.
# For instance, the average price of the Indian crude oil basket is
# taken as $80 for the second half of the current fiscal year. It
# averaged $77.88 in September, according to data from the Petroleum
# Planning and Analysis Cell. The USD/INR exchange rate for the second
# half of FY19 is assumed at =E2=82=B972.50, a level we have now breached. Th=
# e
# combined fiscal deficit of the centre and the states is assumed to be
# 5.9% of GDPTRAI=E2=80=99s new framework for channels and DTH providers came
# into effect from February 1. Though the transition was smooth and
# there was no blackout, the new rules require subscribers of DTH and
# cable to choose channels and packs. The new rules are aimed at
# offering =E2=80=9Cfreedom of choice=E2=80=9D to consumers and give them =
# =E2=80=9Cdirect
# control=E2=80=9D on their monthly bill for television services. With the ne=
# w
# rules in place, subscribers can select only the channels they like.
# One can also remove channels they do not wish to watch from their
# existing channel pack. So, what impact will TRAI=E2=80=99s new rules have o=
# n
# the monthly bill of subscribers? We take a look..
# =C2=A0
# Unsubscribe
# http://m.casaconsultant.com/wiz/index.php/campaigns/qt509dv181895/track-url=
# /hp866jhxd7c12/695a7617d783cbd8b520564e895b1a590c329670
# =C2=A0
# Hi Ashish
#
#
#
# TCS Walkin Interviews For Freshers at Multiple locations Check Complete Det=
# ails
#
# https://clicks.aweber.com/y/ct/?l=3D7zYVz&m=3DhLQ9AxZRM1uTO6c&b=3DO9TBqQaHH=
# XWN6Dh0_L6aaw
#
#
#
# BSF Recruitment Notification
#
# https://clicks.aweber.com/y/ct/?l=3D7zYVz&m=3DhLQ9AxZRM1uTO6c&b=3DZjCPV0Uoa=
# Sv6mBf9FHpDcw
#  With Salary 69,100/-
#
# Address - 29 Haddows Rd
# Chennai West Chennai 600034
# INDIA
#
# To unsubscribe or change subscriber options, visit:
# https://www.aweber.com/z/r/?rIysTCxMrLRsrAysTMzMHLRGtCxMzGwMHKys
#
#
# Indeed Job Alert
# 1 new typing vacancy in Hooghly-Chinsurah, West Bengal
#
# 1 new vacancy
# See matching results on Indeed: https://www.indeed.co.in/jobs?q=typing&hl=en&from=ja&l=Hooghly-Chinsurah%2C+West+Bengal&radius=25&alid=5a896189e4b09960710bc09e&tmtk=1d36dbvhp3hae80c&utm_source=jobseeker_emails&utm_medium=email&utm_campaign=job_alerts&of=1&fr=t
#
#
# Finance/Accounts/Law/Taxation Research Writers
# DEXTEROUS WRITING AND RESEARCH SERVICES - Konnagar, West Bengal
# Good Typing Speed. Withheld good typing skills. Currently looking for FULL TIME Fresher/Experienced academic writers to join our team for the role of Research...
# Indeed - 7-Feb
# https://www.indeed.co.in/rc/clk/dl?jk=cc67ee3d4ca04f7c&from=ja&qd=RnZhMybXSk4M3QtTVGXWoUDZM7-Fq4VfBUKFXg1awEnZD2JiZdfDjqd-7q1lq4igK5cZBBayFzoH71t1EbBiZgePPvVKp2n7ryhPz-RnXar7sheUlPhz27tarClydOHG&rd=AbLHrm6GRQMtYBMzyEs2L1_MKnaSAFGAsD6kfERFt3g&tk=1d36dbvhp3hae80c&alid=5a896189e4b09960710bc09e
#
#
# Salaries estimated if unavailable. When a job posting doesn't include a salary, we estimate it by looking at similar jobs. Estimated salaries are not endorsed by the companies offering those positions and may vary from actual salaries.
#
# Edit this Job Alert: https://subscriptions.indeed.com/update/5a896189e4b09960710bc09e?token=CkCU8lwm_Lvk8Oms-tz2gKk0YmJDuuJ6duWvX1iORN59WS40FCd6C2IofrarpkoKU4fl5tfU4sZAf9a_usYDM48TEiDQslOYsfBvpAhnHxr4FaoATmOW0QwS8HURDab5nFp4ABoQ3UJ80NhJpqWnHFHjpBECXA%3D%3D&co=IN&hl=en&tmtk=1d36dbvhp3hae80c&from=jaEditAlert
#
# Cancel this Job Alert: https://subscriptions.indeed.com/alerts/cancel?token=CkCU8lwm_Lvk8Oms-tz2gKk0YmJDuuJ6duWvX1iORN59WS40FCd6C2IofrarpkoKU4fl5tfU4sZAf9a_usYDM48TEiDQslOYsfBvpAhnHxr4FaoATmOW0QwS8HURDab5nFp4ABoQ3UJ80NhJpqWnHFHjpBECXA%3D%3D&co=IN&hl=en&tmtk=1d36dbvhp3hae80c&subId=5a896189e4b09960710bc09e&rgtk=1d36del0o3cbq805&from=ja
#
# Indeed - one search. all jobs. | Indeed Ireland Operations Limited, 124 St. Stephen's Green, Dublin 2, Ireland
#
# Hi Ashish
#
#
#
# Wipro Conducting Referral Drive Interviews Next Week Check Complete Details
#
# https://clicks.aweber.com/y/ct/?l=3D7zYVz&m=3Dgj.ARmRU61uTO6c&b=3Dj4jOec4rK=
# y8oFR4uq3Tfpg
#
#
#
# RRB Huge Vacancy Recruitment Check Details
#
# https://clicks.aweber.com/y/ct/?l=3D7zYVz&m=3Dgj.ARmRU61uTO6c&b=3DzlFG.ioeY=
# TQ1jZT8Le7EdA
#
# Address - 29 Haddows Rd
# Chennai West Chennai 600034
# INDIA
#
# To unsubscribe or change subscriber options, visit:
# https://www.aweber.com/z/r/?rIysTCxMrLRsrAysTMzMHLRGtCxMzGyMzMzs
#
#
# Hi Ashish,
#
# Your Page Insights summary for Unofficial: Gautam Gambhir
#
# 11 January =E2=80=93 7 February
#
# Your top post
#
# Respond to messages from people
#
# Check your inbox to respond to messages from people contacting your =
# business.
#
# Thanks,
# The Facebook Team
#
#
#
# =3D=3D=3D=3D=3D=3D=3D=3D=3D=3D=3D=3D=3D=3D=3D=3D=3D=3D=3D=3D=3D=3D=3D=3D=
# =3D=3D=3D=3D=3D=3D=3D=3D=3D=3D=3D=3D=3D=3D=3D=3D
# This message was sent to ashishprashar37@gmail.com. If you don't want to =
# receive these emails from Facebook in the future, please follow the link =
# below to unsubscribe.
# https://www.facebook.com/o.php?k=3DAS2LCtVO17NStNBC&u=3D100010314423469&mi=
# d=3D58161e3277c63G5af57743dcadG581622cbd7f35G3d1
# Facebook, Inc., Attention: Community Support, 1 Facebook Way, Menlo Park, =
# CA 94025
# To help keep your account secure, please don't forward this email. Follow =
# the link below to learn more.
# https://www.facebook.com/email_forward_notice/?mid=3D58161e3277c63G5af5774=
# 3dcadG581622cbd7f35G3d1
#
#
# View Online
# http://m.casaconsultant.com/wiz/index.php/campaigns/ne977nyrgj918/track-url=
# /hp866jhxd7c12/689b408e8d8588977080f32ce766af8fc1406855
# According to Pivot charts, the key support level is placed at
# 10,992.6, followed by 10,922.7. If the index starts moving upward, key
# resistance levels to watch out are 11,102.5 and then 11,142.5. Traders
# are advised to remain long with a stop below 10,98 ARMANI
# RICH MAN COLLECTION - Buy Now
# Buy Now
# if Buy Now button doesn't work, click here
# According to Pivot charts, the key support level is placed at
# 10,992.6, followed by 10,922.7. If the index starts moving upward, key
# resistance levels to watch out are 11,102.5 and then 11,142.5. Traders
# are advised to remain long with a stop below 10,980 levels on a
# closing basis and look for a bigger target placed around 11,400
# levels, experts said. The Nifty Bank index closed at 27,402.3. The
# important Pivot level, which will act as crucial support for the
# index, is placed at 27,321.36, followed by 27,240.43. On the upside,
# key resistance levels are placed at 27,455.96, followed by 27,509.63.
# In an interview to CNBC-TV18, top market experts recommend which
# stocks to bet on for good returns: Ashwani Gujral of ashwanigujral.com
# Buy Axis Bank with a stop loss of Rs 720, target of Rs 745 Buy
# Hexaware Tech with a stop loss of Rs 355, target of Rs 372 Buy Maruti
# Suzuki with a stop loss of Rs 7150, target of Rs 7300 Buy Bajaj
# Finance with a stop loss of Rs 2690, target of Rs 2760 Buy Tata Steel
# with a stop loss of Rs 480, target of Rs 510 Mitessh Thakkar of
# mitesshthakkar.com Buy CESC with a stop loss of Rs 716 and target of
# Rs 755 Buy Cipla with a stop loss of Rs 527 and target of Rs 548 Buy
# Hindalco Industries with a stop loss of Rs 207 and target of Rs 219
# Buy PNB Housing Finance with a stop loss of Rs 918 and target of Rs
# 995 Prakash Gaba of prakashgaba.com Buy Bajaj Finance with target at
# Rs 2750-2800 and stop loss at Rs 2650 Buy Grasim Industries with
# target at Rs 775 and stop loss at Rs 716 Buy Hindalco Industries with
# target at Rs 220 and stop loss at Rs 207 Buy State Bank of India with
# target at Rs 295 and stop loss at Rs 285
# =C2=A0
# Unsubscribe
# http://m.casaconsultant.com/wiz/index.php/campaigns/ne977nyrgj918/track-url=
# /hp866jhxd7c12/0362958c16e5c08b9c473868377212fb23654a5e
# =C2=A0
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2652/4042877266.py in <module>
#      12
#      13 for i in s_data[0].split():
# ---> 14     p_holder,f_data=mail.fetch(i,'(RFC822)')
#      15     p_holder,exp_data=f_data[0]  #expaining data
#      16     email_msg=email.message_from_bytes(exp_data)
#
# ~\anaconda3\New folder\lib\imaplib.py in fetch(self, message_set, message_parts)
#     546         """
#     547         name = 'FETCH'
# --> 548         typ, dat = self._simple_command(name, message_set, message_parts)
#     549         return self._untagged_response(typ, dat, name)
#     550
#
# ~\anaconda3\New folder\lib\imaplib.py in _simple_command(self, name, *args)
#    1228     def _simple_command(self, name, *args):
#    1229
# -> 1230         return self._command_complete(name, self._command(name, *args))
#    1231
#    1232
#
# ~\anaconda3\New folder\lib\imaplib.py in _command_complete(self, name, tag)
#    1045             self._check_bye()
#    1046         try:
# -> 1047             typ, data = self._get_tagged_response(tag, expect_bye=logout)
#    1048         except self.abort as val:
#    1049             raise self.abort('command: %s => %s' % (name, val))
#
# ~\anaconda3\New folder\lib\imaplib.py in _get_tagged_response(self, tag, expect_bye)
#    1171
#    1172             try:
# -> 1173                 self._get_response()
#    1174             except self.abort as val:
#    1175                 if __debug__:
#
# ~\anaconda3\New folder\lib\imaplib.py in _get_response(self)
#    1120                     if self.debug >= 4:
#    1121                         self._mesg('read literal size %s' % size)
# -> 1122                 data = self.read(size)
#    1123
#    1124                 # Store response with literal as tuple
#
# ~\anaconda3\New folder\lib\imaplib.py in read(self, size)
#     316     def read(self, size):
#     317         """Read 'size' bytes from remote."""
# --> 318         return self.file.read(size)
#     319
#     320
#
# ~\anaconda3\New folder\lib\socket.py in readinto(self, b)
#     702         while True:
#     703             try:
# --> 704                 return self._sock.recv_into(b)
#     705             except timeout:
#     706                 self._timeout_occurred = True
#
# ~\anaconda3\New folder\lib\ssl.py in recv_into(self, buffer, nbytes, flags)
#    1239                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240                   self.__class__)
# -> 1241             return self.read(nbytes, buffer)
#    1242         else:
#    1243             return super().recv_into(buffer, nbytes, flags)
#
# ~\anaconda3\New folder\lib\ssl.py in read(self, len, buffer)
#    1097         try:
#    1098             if buffer is not None:
# -> 1099                 return self._sslobj.read(len, buffer)
#    1100             else:
#    1101                 return self._sslobj.read(len)
#
# ConnectionAbortedError: [WinError 10053] An established connection was aborted by the software in your host machine
